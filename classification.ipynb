# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import scipy
from numpy.random import randint
from sklearn import metrics

# %%
# Out:
# Positive: 3222 (62.06%)

# %%
NUM_EXPS = 5

# %%
def get_predictions_for_layer(layer_csv):
    df = pd.read_csv(layer_csv)
    df = df.drop('Unnamed: 0', axis=1)
    y = df['0']
    X = df.drop('0', axis=1)
    n = len(y)
    print(f"Positive: {sum(y)} ({sum(y)/len(y)*100:0.2f}%)")

    y_pred = 0.0
    accuracy = 0.0
    precision = 0.0
    recall = 0.0
    f1 = 0.0
    roc_auc = 0.0
    np.random.seed(seed=42)
    for i in range(NUM_EXPS):
        idxs = randint(0, n, int(0.2*n))
        clf = LogisticRegression(random_state=42, max_iter=1000)
        clf.fit(X.iloc[X.index.isin(idxs)], y[y.index.isin(idxs)])
        y_true = y[~y.index.isin(idxs)]
        y_pred = clf.predict(X.iloc[~X.index.isin(idxs)])
        y_pred_proba = clf.predict_proba(X.iloc[~X.index.isin(idxs)])[:, 1]
        roc_auc += metrics.roc_auc_score(y_true, y_pred_proba)
        accuracy += metrics.accuracy_score(y_true, y_pred)
        precision += metrics.precision_score(y_true, y_pred)
        recall += metrics.recall_score(y_true, y_pred)
        f1 += metrics.f1_score(y_true, y_pred)
    print(f"accuracy: {accuracy/NUM_EXPS*100:0.2f}%")
    print(f"precision: {precision/NUM_EXPS*100:0.2f}%")
    print(f"recall: {recall/NUM_EXPS*100:0.2f}%")
    print(f"f1: {f1/NUM_EXPS*100:0.2f}%")
    print(f"ROC_AUC: {roc_auc/NUM_EXPS*100:0.2f}%")

# %%
for layer_num in range(1, 34):
    layer_filename = f"layer{layer_num}.csv"
    print(layer_filename)
    get_predictions_for_layer(layer_filename)
    print("----------------------------------")
# Out:
# layer1.csv
# Positive: 3222 (62.06%)
# accuracy: 63.10%
# precision: 63.07%
# recall: 97.41%
# f1: 76.56%
# ROC_AUC: 60.93%
# ----------------------------------
# layer2.csv
# Positive: 3222 (62.06%)
# accuracy: 64.19%
# precision: 65.02%
# recall: 91.28%
# f1: 75.93%
# ROC_AUC: 62.47%
# ----------------------------------
# layer3.csv
# Positive: 3222 (62.06%)
# accuracy: 64.19%
# precision: 65.02%
# recall: 91.28%
# f1: 75.93%
# ROC_AUC: 62.47%
# ----------------------------------
# layer4.csv
# Positive: 3222 (62.06%)
# accuracy: 64.96%
# precision: 65.80%
# recall: 90.36%
# f1: 76.14%
# ROC_AUC: 64.13%
# ----------------------------------
# layer5.csv
# Positive: 3222 (62.06%)
# accuracy: 66.24%
# precision: 67.81%
# recall: 86.71%
# f1: 76.06%
# ROC_AUC: 66.86%
# ----------------------------------
# layer6.csv
# Positive: 3222 (62.06%)
# accuracy: 66.62%
# precision: 69.30%
# recall: 82.85%
# f1: 75.43%
# ROC_AUC: 67.92%
# ----------------------------------
# layer7.csv
# Positive: 3222 (62.06%)
# accuracy: 67.01%
# precision: 70.13%
# recall: 81.49%
# f1: 75.33%
# ROC_AUC: 68.51%
# ----------------------------------
# layer8.csv
# Positive: 3222 (62.06%)
# accuracy: 66.84%
# precision: 70.65%
# recall: 79.55%
# f1: 74.78%
# ROC_AUC: 68.56%
# ----------------------------------
# layer9.csv
# Positive: 3222 (62.06%)
# accuracy: 67.57%
# precision: 71.65%
# recall: 78.92%
# f1: 75.04%
# ROC_AUC: 69.74%
# ----------------------------------
# layer10.csv
# Positive: 3222 (62.06%)
# accuracy: 67.87%
# precision: 72.08%
# recall: 78.62%
# f1: 75.15%
# ROC_AUC: 70.40%
# ----------------------------------
# layer11.csv
# Positive: 3222 (62.06%)
# accuracy: 68.82%
# precision: 72.83%
# recall: 79.31%
# f1: 75.87%
# ROC_AUC: 71.05%
# ----------------------------------
# layer12.csv
# Positive: 3222 (62.06%)
# accuracy: 68.30%
# precision: 72.53%
# recall: 78.65%
# f1: 75.41%
# ROC_AUC: 70.34%
# ----------------------------------
# layer13.csv
# Positive: 3222 (62.06%)
# accuracy: 68.58%
# precision: 72.74%
# recall: 78.88%
# f1: 75.63%
# ROC_AUC: 70.53%
# ----------------------------------
# layer14.csv
# Positive: 3222 (62.06%)
# accuracy: 68.63%
# precision: 73.04%
# recall: 78.30%
# f1: 75.51%
# ROC_AUC: 70.78%
# ----------------------------------
# layer15.csv
# Positive: 3222 (62.06%)
# accuracy: 68.45%
# precision: 72.90%
# recall: 78.10%
# f1: 75.36%
# ROC_AUC: 70.63%
# ----------------------------------
# layer16.csv
# Positive: 3222 (62.06%)
# accuracy: 68.38%
# precision: 72.98%
# recall: 77.76%
# f1: 75.24%
# ROC_AUC: 70.73%
# ----------------------------------
# layer17.csv
# Positive: 3222 (62.06%)
# accuracy: 68.18%
# precision: 72.96%
# recall: 77.26%
# f1: 74.99%
# ROC_AUC: 70.45%
# ----------------------------------
# layer18.csv
# Positive: 3222 (62.06%)
# accuracy: 68.22%
# precision: 72.92%
# recall: 77.48%
# f1: 75.07%
# ROC_AUC: 70.73%
# ----------------------------------
# layer19.csv
# Positive: 3222 (62.06%)
# accuracy: 68.10%
# precision: 73.20%
# recall: 76.51%
# f1: 74.76%
# ROC_AUC: 70.69%
# ----------------------------------
# layer20.csv
# Positive: 3222 (62.06%)
# accuracy: 68.03%
# precision: 73.23%
# recall: 76.31%
# f1: 74.68%
# ROC_AUC: 70.81%
# ----------------------------------
# layer21.csv
# Positive: 3222 (62.06%)
# accuracy: 67.89%
# precision: 72.98%
# recall: 76.51%
# f1: 74.64%
# ROC_AUC: 70.54%
# ----------------------------------
# layer22.csv
# Positive: 3222 (62.06%)
# accuracy: 67.71%
# precision: 72.90%
# recall: 76.22%
# f1: 74.47%
# ROC_AUC: 70.38%
# ----------------------------------
# layer23.csv
# Positive: 3222 (62.06%)
# accuracy: 67.34%
# precision: 72.69%
# recall: 75.78%
# f1: 74.14%
# ROC_AUC: 70.10%
# ----------------------------------
# layer24.csv
# Positive: 3222 (62.06%)
# accuracy: 67.00%
# precision: 72.53%
# recall: 75.21%
# f1: 73.80%
# ROC_AUC: 69.89%
# ----------------------------------
# layer25.csv
# Positive: 3222 (62.06%)
# accuracy: 66.96%
# precision: 72.50%
# recall: 75.15%
# f1: 73.76%
# ROC_AUC: 69.69%
# ----------------------------------
# layer26.csv
# Positive: 3222 (62.06%)
# accuracy: 67.07%
# precision: 72.51%
# recall: 75.43%
# f1: 73.89%
# ROC_AUC: 69.50%
# ----------------------------------
# layer27.csv
# Positive: 3222 (62.06%)
# accuracy: 67.15%
# precision: 72.49%
# recall: 75.70%
# f1: 74.01%
# ROC_AUC: 69.58%
# ----------------------------------
# layer28.csv
# Positive: 3222 (62.06%)
# accuracy: 67.10%
# precision: 72.57%
# recall: 75.38%
# f1: 73.90%
# ROC_AUC: 69.64%
# ----------------------------------
# layer29.csv
# Positive: 3222 (62.06%)
# accuracy: 67.04%
# precision: 72.52%
# recall: 75.34%
# f1: 73.85%
# ROC_AUC: 69.48%
# ----------------------------------
# layer30.csv
# Positive: 3222 (62.06%)
# accuracy: 66.78%
# precision: 72.54%
# recall: 74.65%
# f1: 73.53%
# ROC_AUC: 69.53%
# ----------------------------------
# layer31.csv
# Positive: 3222 (62.06%)
# accuracy: 66.92%
# precision: 72.70%
# recall: 74.62%
# f1: 73.60%
# ROC_AUC: 69.61%
# ----------------------------------
# layer32.csv
# Positive: 3222 (62.06%)
# accuracy: 66.99%
# precision: 72.95%
# recall: 74.24%
# f1: 73.54%
# ROC_AUC: 69.41%
# ----------------------------------
# layer33.csv
# Positive: 3222 (62.06%)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accuracy: 65.95%
# precision: 72.48%
# recall: 72.56%
# f1: 72.48%
# ROC_AUC: 68.13%
# ----------------------------------

# %%
# Out:
#            0.1         1         2  ...      4093      4094      4095
# 0     0.012901  0.007127 -0.010630  ...  0.003006 -0.006576 -0.011035
# 1    -0.002121 -0.006792  0.003629  ... -0.002032 -0.021791  0.007529
# 2     0.000934 -0.004428  0.000598  ...  0.004380 -0.025252  0.007186
# 3    -0.011516  0.001039 -0.004985  ...  0.033128 -0.003469  0.011452
# 4     0.018092  0.002145  0.006279  ...  0.002020 -0.021013  0.025115
# ...        ...       ...       ...  ...       ...       ...       ...
# 5187  0.041397  0.003060  0.023776  ... -0.040758 -0.020868  0.019912
# 5188  0.041493  0.006807  0.020266  ... -0.038899 -0.016973  0.018510
# 5189  0.040495 -0.000661  0.027179  ... -0.037136 -0.019277  0.020389
# 5190  0.021248 -0.005593  0.005585  ... -0.058740 -0.006677  0.001453
# 5191  0.010145 -0.027534  0.001397  ... -0.011189 -0.004629 -0.012369
#
# [5192 rows x 4096 columns]
